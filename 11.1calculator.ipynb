# %%
class Calculator:
    def __init__(self):
        self.numbers = []

    def accept(self, *args):
        self.numbers.extend(args)

    def addition(self):
        x = sum(self.numbers)
        print("Addition of", end=' ')
        for i in self.numbers:
            print(i, end=' + ')
        print("= ", x)

    def subtraction(self):
        diff = self.numbers[0]    
        for each in range(1, len(self.numbers)):     
            diff = diff - self.numbers[each]
        print("Subtraction of", end=' ')
        for i in self.numbers:
            print(i, end=' - ')
        print("= ", diff)

    def multiplication(self):
        mult = self.numbers[0]
        for each in range(1, len(self.numbers)):
            mult = mult * self.numbers[each]
        print("Multiplication of", end=' ')
        for i in self.numbers:
            print(i, end=' * ')
        print("= ", mult)

    def division(self):
        div = self.numbers[0]
        for each in range(1, len(self.numbers)):
            if self.numbers[each]!= 0:
                div = div / self.numbers[each]
            else:
                print("Error: Division by zero is not allowed.")
                return
        print("Division of", end=' ')
        for i in self.numbers:
            print(i, end=' / ')
        print("= ", div)

    def modulus(self):
        mod = self.numbers[0]
        for each in range(1, len(self.numbers)):
            mod = mod % self.numbers[each]
        print("Modulus of", end=' ')
        for i in self.numbers:
            print(i, end=' % ')
        print("= ", mod)

    def exponent(self):
        exp = self.numbers[0]
        for each in range(1, len(self.numbers)):
            exp = exp ** self.numbers[each]
        print("Exponent of", end=' ')
        for i in self.numbers:
            print(i, end=' ** ')
        print("= ", exp)

    def remainder(self):
        rem = self.numbers[0]
        for each in range(1, len(self.numbers)):
            rem = rem // self.numbers[each]
        print("Remainder of", end=' ')
        for i in self.numbers:
            print(i, end=' // ')
        print("= ", rem)

    def details(self):
        print("""
        \n-------------------------------------------
        \nWhat do you want to perform:
        1.Addition
        2.Subtraction
        3.Multiplication
        4.Division
        5.Modulus
        6.Exponent
        7.Remainder
        8.Exit
        \n-------------------------------------------
        """)
        while True:
            try:
                print("[1.Addition/2.Subtraction/3.Multiplication/4.Division/5.Modulus/6.Exponent/7.Remainder/8.Exit]")
                print("\n")
                option = int(input('Choose any option from above list: '))
                
            except ValueError:
                print('Error: Enter a correct option.')
                continue
            else:
                if option == 8:
                    print("          ----------Thanks for using my Calculator-------------")
                    break
                while True:
                    user_input = input("Enter a number (Type '=' to stop and perform calculation): ")
                    if user_input == '=':
                        break
                    try:
                        num = float(user_input)
                        self.accept(num)
                    except ValueError:
                        print("Invalid input. Please enter a valid number or 'ok' to perform calculation.")
                if option == 1:
                    print("-----------------------------------------\n")
                    print("ADDITION :-")
                    self.addition()
                    print("-----------------------------------------\n")
                elif option == 2:
                    print("-----------------------------------------\n")
                    print("SUBTRACTION :-")
                    self.subtraction()
                    print("-----------------------------------------\n")
                elif option == 3:
                    print("-----------------------------------------\n")
                    print("MULTIPLICATION :-")
                    self.multiplication()
                    print("-----------------------------------------\n")
                elif option == 4:
                    print("-----------------------------------------\n")
                    print("DIVISION :-")
                    self.division()
                    print("-----------------------------------------\n")
                elif option == 5:
                    print("-----------------------------------------\n")
                    print("MODULUS :-")
                    self.modulus()
                    print("-----------------------------------------\n")
                elif option == 6:
                    print("-----------------------------------------\n")
                    print("EXPONENT :-")
                    self.exponent()
                    print("-----------------------------------------\n")
                elif option == 7:
                    print("-----------------------------------------\n")
                    print("REMAINDER :-")
                    self.remainder()
                    print("-----------------------------------------\n")
                else:
                    print('Error: Enter a correct option.')
                self.numbers = []

try:
    Calculator().details()
except:
    print('There might be some issue visit later')
# Out:
#
# -------------------------------------------
#
# What do you want to perform:
#         1.Addition
#         2.Subtraction
#         3.Multiplication
#         4.Division
#         5.Modulus
#         6.Exponent
#         7.Remainder
#         8.Exit
#
# -------------------------------------------
#
# [1.Addition/2.Subtraction/3.Multiplication/4.Division/5.Modulus/6.Exponent/7.Remainder/8.Exit]
# Choose any option from above list:  1
# Enter a number (Type '=' to stop and perform calculation):  12
# Enter a number (Type '=' to stop and perform calculation):  24
# Enter a number (Type '=' to stop and perform calculation):  =
# -----------------------------------------
#
# ADDITION :-
# Addition of 12.0 + 24.0 + =  36.0
# -----------------------------------------
#
# [1.Addition/2.Subtraction/3.Multiplication/4.Division/5.Modulus/6.Exponent/7.Remainder/8.Exit]
# Choose any option from above list:  8
#           ----------Thanks for using my Calculator-------------

# %%
class Calculator:
    def __init__(self):
        self.numbers = []

    def accept(self, *args):
        self.numbers.extend(args)

    def addition(self):
        x = sum(self.numbers)
        print("Addition of", end=' ')
        for i in range(len(self.numbers) - 1):
            print(self.numbers[i], end=' + ')
        print(self.numbers[-1], end=' = ')
        print(x)

    def subtraction(self):
        diff = self.numbers[0]    
        for each in range(1, len(self.numbers)):     
            diff = diff - self.numbers[each]
        print("Subtraction of", end=' ')
        for i in range(len(self.numbers) - 1):
            print(self.numbers[i], end=' - ')
        print(self.numbers[-1], end=' = ')
        print(diff)

    def multiplication(self):
        mult = self.numbers[0]
        for each in range(1, len(self.numbers)):
            mult = mult * self.numbers[each]
        print("Multiplication of", end=' ')
        for i in range(len(self.numbers) - 1):
            print(self.numbers[i], end=' * ')
        print(self.numbers[-1], end=' = ')
        print(mult)

    def division(self):
        div = self.numbers[0]
        for each in range(1, len(self.numbers)):
            if self.numbers[each]!= 0:
                div = div / self.numbers[each]
            else:
                print("Error: Division by zero is not allowed.")
                return
        print("Division of", end=' ')
        for i in range(len(self.numbers) - 1):
            print(self.numbers[i], end=' / ')
        print(self.numbers[-1], end=' = ')
        print(div)

    def modulus(self):
        mod = self.numbers[0]
        for each in range(1, len(self.numbers)):
            mod = mod % self.numbers[each]
        print("Modulus of", end=' ')
        for i in range(len(self.numbers) - 1):
            print(self.numbers[i], end=' % ')
        print(self.numbers[-1], end=' = ')
        print(mod)

    def exponent(self):
        exp = self.numbers[0]
        for each in range(1, len(self.numbers)):
            exp = exp ** self.numbers[each]
        print("Exponent of", end=' ')
        for i in range(len(self.numbers) - 1):
            print(self.numbers[i], end=' ** ')
        print(self.numbers[-1], end=' = ')
        print(exp)

    def remainder(self):
        rem = self.numbers[0]
        for each in range(1, len(self.numbers)):
            rem = rem // self.numbers[each]
        print("Remainder of", end=' ')
        for i in range(len(self.numbers) - 1):
            print(self.numbers[i], end=' // ')
        print(self.numbers[-1], end=' = ')
        print(rem)

    def details(self):
        print("""
        \n-------------------------------------------
        \nWhat do you want to perform:
        1.Addition
        2.Subtraction
        3.Multiplication
        4.Division
        5.Modulus
        6.Exponent
        7.Remainder
        8.Exit
        \n-------------------------------------------
        """)
        while True:
            try:
                print("[1.Addition/2.Subtraction/3.Multiplication/4.Division/5.Modulus/6.Exponent/7.Remainder/8.Exit]")
                print("\n")
                option = int(input('Choose any option from above list: '))
                
            except ValueError:
                print('Error: Enter a correct option.')
                continue
            else:
                if option == 8:
                    print("          ----------Thanks for using my Calculator-------------")
                    break
                while True:
                    user_input = input("Enter a number (Type '=' to stop and perform calculation): ")
                    if user_input == '=':
                        break
                    try:
                        num = float(user_input)
                        self.accept(num)
                    except ValueError:
                        print("Invalid input. Please enter a valid number or 'ok' to perform calculation.")
                if option == 1:
                    print("-----------------------------------------\n")
                    print("ADDITION :-")
                    self.addition()
                    print("-----------------------------------------\n")
                elif option == 2:
                    print("-----------------------------------------\n")
                    print("SUBTRACTION :-")
                    self.subtraction()
                    print("-----------------------------------------\n")
                elif option == 3:
                    print("-----------------------------------------\n")
                    print("MULTIPLICATION :-")
                    self.multiplication()
                    print("-----------------------------------------\n")
                elif option == 4:
                    print("-----------------------------------------\n")
                    print("DIVISION :-")
                    self.division()
                    print("-----------------------------------------\n")
                elif option == 5:
                    print("-----------------------------------------\n")
                    print("MODULUS :-")
                    self.modulus()
                    print("-----------------------------------------\n")
                elif option == 6:
                    print("-----------------------------------------\n")
                    print("EXPONENT :-")
                    self.exponent()
                    print("-----------------------------------------\n")
                elif option == 7:
                    print("-----------------------------------------\n")
                    print("REMAINDER :-")
                    self.remainder()
                    print("-----------------------------------------\n")
                else:
                    print('Error: Enter a correct option.')
                self.numbers = []

try:
    Calculator().details()
except:
    print('There might be some issue visit later')
# Out:
#
# -------------------------------------------
#
# What do you want to perform:
#         1.Addition
#         2.Subtraction
#         3.Multiplication
#         4.Division
#         5.Modulus
#         6.Exponent
#         7.Remainder
#         8.Exit
#
# -------------------------------------------
#
# [1.Addition/2.Subtraction/3.Multiplication/4.Division/5.Modulus/6.Exponent/7.Remainder/8.Exit]
# Choose any option from above list:  1
# Enter a number (Type '=' to stop and perform calculation):  12
# Enter a number (Type '=' to stop and perform calculation):  15
# Enter a number (Type '=' to stop and perform calculation):  17
# Enter a number (Type '=' to stop and perform calculation):  =
# -----------------------------------------
#
# ADDITION :-
# Addition of 12.0 + 15.0 + 17.0 = 44.0
# -----------------------------------------
#
# [1.Addition/2.Subtraction/3.Multiplication/4.Division/5.Modulus/6.Exponent/7.Remainder/8.Exit]
# Choose any option from above list:  2
# Enter a number (Type '=' to stop and perform calculation):  78
# Enter a number (Type '=' to stop and perform calculation):  98
# Enter a number (Type '=' to stop and perform calculation):  =
# -----------------------------------------
#
# SUBTRACTION :-
# Subtraction of 78.0 - 98.0 = -20.0
# -----------------------------------------
#
# [1.Addition/2.Subtraction/3.Multiplication/4.Division/5.Modulus/6.Exponent/7.Remainder/8.Exit]
# Choose any option from above list:  3
# Enter a number (Type '=' to stop and perform calculation):  74
# Enter a number (Type '=' to stop and perform calculation):  45
# Enter a number (Type '=' to stop and perform calculation):  49
# Enter a number (Type '=' to stop and perform calculation):  75
# Enter a number (Type '=' to stop and perform calculation):  63
# Enter a number (Type '=' to stop and perform calculation):  95
# Enter a number (Type '=' to stop and perform calculation):  =
# -----------------------------------------
#
# MULTIPLICATION :-
# Multiplication of 74.0 * 45.0 * 49.0 * 75.0 * 63.0 * 95.0 = 73242933750.0
# -----------------------------------------
#
# [1.Addition/2.Subtraction/3.Multiplication/4.Division/5.Modulus/6.Exponent/7.Remainder/8.Exit]
# Choose any option from above list:  4
# Enter a number (Type '=' to stop and perform calculation):  78
# Enter a number (Type '=' to stop and perform calculation):  96
# Enter a number (Type '=' to stop and perform calculation):  35
# Enter a number (Type '=' to stop and perform calculation):  =
# -----------------------------------------
#
# DIVISION :-
# Division of 78.0 / 96.0 / 35.0 = 0.023214285714285715
# -----------------------------------------
#
# [1.Addition/2.Subtraction/3.Multiplication/4.Division/5.Modulus/6.Exponent/7.Remainder/8.Exit]
# Choose any option from above list:  5
# Enter a number (Type '=' to stop and perform calculation):  78
# Enter a number (Type '=' to stop and perform calculation):  5
# Enter a number (Type '=' to stop and perform calculation):  =
# -----------------------------------------
#
# MODULUS :-
# Modulus of 78.0 % 5.0 = 3.0
# -----------------------------------------
#
# [1.Addition/2.Subtraction/3.Multiplication/4.Division/5.Modulus/6.Exponent/7.Remainder/8.Exit]
# Choose any option from above list:  6
# Enter a number (Type '=' to stop and perform calculation):  2
# Enter a number (Type '=' to stop and perform calculation):  4
# Enter a number (Type '=' to stop and perform calculation):  =
# -----------------------------------------
#
# EXPONENT :-
# Exponent of 2.0 ** 4.0 = 16.0
# -----------------------------------------
#
# [1.Addition/2.Subtraction/3.Multiplication/4.Division/5.Modulus/6.Exponent/7.Remainder/8.Exit]
# Choose any option from above list:  7
# Enter a number (Type '=' to stop and perform calculation):  3
# Enter a number (Type '=' to stop and perform calculation):  2
# Enter a number (Type '=' to stop and perform calculation):  =
# -----------------------------------------
#
# REMAINDER :-
# Remainder of 3.0 // 2.0 = 1.0
# -----------------------------------------
#
# [1.Addition/2.Subtraction/3.Multiplication/4.Division/5.Modulus/6.Exponent/7.Remainder/8.Exit]
# Choose any option from above list:  8
#           ----------Thanks for using my Calculator-------------

# %%
# Create online library Management System: Using Oops
# Create library class that includes the following methods:-
#----------------------------------------------------------------
# Diplay(): To display the available books.
# Lendbook(): To lend a book to a user.
# Addbook(): To add a book to the library.
# Returnbook(): To return the book to the librarey.
#------------------------------------------------------------
# Maintain a dictionary for the users who own a book. Dictionary should take book name as a key and name of the person as 
# a value. Wheneven you lend a book to a user, you should maintain dictionary.
#------------------------------------------------------------------------------------------------------------------------------
